# %% [markdown]
# <a href="https://colab.research.google.com/github/fedhere/MLTSA_FBianco/blob/master/CodeExamples/KaggledataloadTS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import pylab as pl
import glob
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pl.style.use("https://raw.githubusercontent.com/fedhere/MLTSA_FBianco/master/fbb.mplstyle")

# %% [markdown]
# # data ingestion

# %%
# download kaggle economic data
#https://www.kaggle.com/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/data#a.us.txt

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.6/dist-packages (1.5.6)
# Requirement already satisfied: certifi in /usr/local/lib/python3.6/dist-packages (from kaggle) (2019.11.28)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.6.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from kaggle) (4.28.1)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.12.0)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.6/dist-packages (from kaggle) (4.0.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.21.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.6/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (3.0.4)

# %%
from google.colab import drive

drive.mount("/content/gdrive")
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
cd gdrive/My\ Drive/
# Out:
# /content/gdrive/My Drive

# %%
ls kaggle.json
# Out:
# kaggle.json

# %%
# !chmod 600 kaggle.json

# %%
import json
import os
envs = json.load(open("kaggle.json", "r"))
os.environ["KAGGLE_USERNAME"] = envs['username']
os.environ["KAGGLE_KEY"] = envs['key']

# %%
os.environ
# Out:
# environ({'ENV': '/root/.bashrc', 'GCS_READ_CACHE_BLOCK_SIZE_MB': '16', 'CLOUDSDK_CONFIG': '/content/.config', 'CUDA_VERSION': '10.1.243', 'PATH': '/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin:/opt/bin', 'HOME': '/root', 'LD_LIBRARY_PATH': '/usr/local/nvidia/lib:/usr/local/nvidia/lib64', 'LANG': 'en_US.UTF-8', 'SHELL': '/bin/bash', 'LIBRARY_PATH': '/usr/local/cuda/lib64/stubs', 'CUDA_PKG_VERSION': '10-1=10.1.243-1', 'SHLVL': '1', 'GCE_METADATA_TIMEOUT': '0', 'NCCL_VERSION': '2.4.8', 'NVIDIA_VISIBLE_DEVICES': 'all', 'TF_FORCE_GPU_ALLOW_GROWTH': 'true', 'DEBIAN_FRONTEND': 'noninteractive', 'CUDNN_VERSION': '7.6.5.32', 'LAST_FORCED_REBUILD': '20200204', 'JPY_PARENT_PID': '18', 'PYTHONPATH': '/env/python', 'DATALAB_SETTINGS_OVERRIDES': '{"kernelManagerProxyPort":6000,"kernelManagerProxyHost":"172.28.0.3","jupyterArgs":["--ip=\\"172.28.0.2\\""]}', 'NO_GCE_CHECK': 'True', 'GLIBCXX_FORCE_NEW': '1', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', '_': '/tools/node/bin/node', 'LD_PRELOAD': '/usr/lib/x86_64-linux-gnu/libtcmalloc.so.4', 'NVIDIA_REQUIRE_CUDA': 'cuda>=10.1 brand=tesla,driver>=384,driver<385 brand=tesla,driver>=396,driver<397 brand=tesla,driver>=410,driver<411', 'OLDPWD': '/', 'HOSTNAME': '0e2928638bf9', 'COLAB_GPU': '0', 'PWD': '/', 'GLIBCPP_FORCE_NEW': '1', 'PYTHONWARNINGS': 'ignore:::pip._internal.cli.base_command', 'TBE_CREDS_ADDR': '172.28.0.1:8008', 'TERM': 'xterm-color', 'CLICOLOR': '1', 'PAGER': 'cat', 'GIT_PAGER': 'cat', 'MPLBACKEND': 'module://ipykernel.pylab.backend_inline', 'KAGGLE_USERNAME': 'fedhere', 'KAGGLE_KEY': '0edeec1540b4366ee8216c3e20103272'})

# %%
#check that it worked by listing the kaggle datasets
# !kaggle datasets
# Out:
# usage: kaggle datasets [-h]
#                        {list,files,download,create,version,init,metadata,status}
#                        ...
# kaggle datasets: error: too few arguments

# %%
# !kaggle competitions list -s health
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.6 / client 1.5.4)
# aaron7sun/stocknews                                      Daily News for Stock Market Prediction                6MB  2019-11-13 18:22:52          28197
# jeegarmaru/campaign-contributions-19902016               US Federal Campaign Finance data 1990-2016            1GB  2019-11-24 16:50:31             25
# hhenry/finance-factoring-ibm-late-payment-histories      Finance Factoring - IBM Late Payment Histories       57KB  2019-06-17 16:27:31            344
# PythonforSASUsers/hpindex                                Home Price Index                                    729KB  2016-12-07 04:35:18           2518
# qks1lver/amex-nyse-nasdaq-stock-histories                AMEX, NYSE, NASDAQ stock histories                  509MB  2019-04-21 05:25:28           4120
# camnugent/sandp500                                       S&P 500 stock data                                   19MB  2018-02-10 03:15:53          24566

# %%
# !kaggle datasets list -s stock
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.6 / client 1.5.4)
# ref                                                       title                                              size  lastUpdated          downloadCount
# --------------------------------------------------------  ------------------------------------------------  -----  -------------------  -------------
# borismarjanovic/price-volume-data-for-all-us-stocks-etfs  Huge Stock Market Dataset                         492MB  2017-11-16 14:53:29          49287
# dgawlik/nyse                                              New York Stock Exchange                            31MB  2017-02-22 10:18:25          37441
# camnugent/sandp500                                        S&P 500 stock data                                 19MB  2018-02-10 03:15:53          24566
# aaron7sun/stocknews                                       Daily News for Stock Market Prediction              6MB  2019-11-13 18:22:52          28197
# rpaguirre/tesla-stock-price                               Tesla Stock Price                                  34KB  2017-03-19 03:14:36           1174
# szrlee/stock-time-series-20050101-to-20171231             DJIA 30 Stock Time Series                           3MB  2018-01-03 08:29:18           9831
# shivinder/googlestockpricing                              Stock Pricing                                     147KB  2017-01-18 10:35:06           1160
# qks1lver/amex-nyse-nasdaq-stock-histories                 AMEX, NYSE, NASDAQ stock histories                509MB  2019-04-21 05:25:28           4120
# usfundamentals/us-stocks-fundamentals                     US Stocks Fundamentals (XBRL)                      31MB  2019-11-14 06:20:39           5293
# gbonesso/b3-stock-quotes                                  Brazillian Stock Quotes                           413MB  2020-01-21 17:16:19            437
# ramamet4/nse-stocks-database                              NSE India stocks (Indices)                          8MB  2017-05-11 18:21:22           2567
# daiearth22/uniqlo-fastretailing-stock-price-prediction    Uniqlo (FastRetailing) Stock Price Prediction      25KB  2017-08-07 04:54:01           1526
# timoboz/tesla-stock-data-from-2010-to-2020                Tesla stock data from 2010 to 2020                 46KB  2020-02-04 17:15:32           1449
# timoboz/stock-data-dow-jones                              EOD data for all Dow Jones stocks                   2MB  2019-06-12 22:36:07           2537
# ehallmar/daily-historical-stock-prices-1970-2018          Daily Historical Stock Prices (1970 - 2018)       469MB  2018-08-26 16:55:34           2781
# rohan8594/stock-data                                      Stock Data                                        466KB  2017-11-09 21:41:22           1949
# rishisankineni/text-similarity                            Text Similarity                                    55KB  2017-03-19 08:02:56           2445
# minatverma/nse-stocks-data                                NSE Stocks Data                                    30MB  2018-01-01 18:26:16           3378
# atulanandjha/national-stock-exchange-time-series          National Stock Exchange : Time Series              29KB  2019-12-02 23:49:29            179
# alvarob96/spanish-stocks-historical-data                  Spanish Stocks Historical Data from 2000 to 2019    1MB  2019-06-07 16:08:00           1943

# %%
# !mkdir TESLA

# %%
cd TESLA
# Out:
# /content/gdrive/My Drive/MLTSA2020/data/TESLA

# %%
# !mkdir data

# %%
cd data
# Out:
# /content/gdrive/My Drive/MLTSA2020/data/TESLA/data

# %%
# !kaggle datasets download timoboz/tesla-stock-data-from-2010-to-2020
# Out:
# Downloading tesla-stock-data-from-2010-to-2020.zip to /content/gdrive/My Drive/MLTSA2020/data/TESLA/data
#   0% 0.00/46.1k [00:00<?, ?B/s]
# 100% 46.1k/46.1k [00:00<00:00, 5.64MB/s]

# %%
# !ls
# Out:
# tesla-stock-data-from-2010-to-2020.zip

# %%
# !unzip tesla-stock-data-from-2010-to-2020.zip
# Out:
# Archive:  tesla-stock-data-from-2010-to-2020.zip
#   inflating: TSLA.csv

# %%
# this will be a bit more complicated because you will download a folder and will have to read some files from it.

# %%
pd.read_csv("TSLA.csv")
# Out:
#             Date        Open        High  ...       Close   Adj Close    Volume
# 0     2010-06-29   19.000000   25.000000  ...   23.889999   23.889999  18766300
# 1     2010-06-30   25.790001   30.420000  ...   23.830000   23.830000  17187100
# 2     2010-07-01   25.000000   25.920000  ...   21.959999   21.959999   8218800
# 3     2010-07-02   23.000000   23.100000  ...   19.200001   19.200001   5139800
# 4     2010-07-06   20.000000   20.000000  ...   16.110001   16.110001   6866900
# ...          ...         ...         ...  ...         ...         ...       ...
# 2411  2020-01-28  568.489990  576.809998  ...  566.900024  566.900024  11788500
# 2412  2020-01-29  575.690002  589.799988  ...  580.989990  580.989990  17801500
# 2413  2020-01-30  632.419983  650.880005  ...  640.809998  640.809998  29005700
# 2414  2020-01-31  640.000000  653.000000  ...  650.570007  650.570007  15719300
# 2415  2020-02-03  673.690002  786.140015  ...  780.000000  780.000000  47065000
#
# [2416 rows x 7 columns]

# %%
tesla = pd.read_csv("TSLA.csv")

# %%
tesla.shape
# Out:
# (2416, 6)

# %% [markdown]
# #  data inspection
#
# plot each time series (ts)

# %%
tesla.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
tesla.set_index("Date", inplace=True)

# %%
for c in tesla.columns:
    print(c)
    fig, ax = pl.subplots(figsize=(10,4))
    tesla.plot(y=c, ax=ax, rot=75)

tesla.shape
# Out:
# Open
# High
# Low
# Close
# Adj Close
# Volume
# (2416, 6)

# %% [markdown]
# ## visualizing correlations

# %% [markdown]
# use ```pandas.plotting.scatter_matrix```  to look at the relationship between lightcurves
#
# plot the pairwise correlation as a heatmap using ```pl.imshow()```. You can access the pairwise correlation with the dataframe method ```df.corr()```

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(tesla, figsize=(25,25), color="#222222");

# %%
tesla.corr()
# Out:
#                Open      High       Low     Close  Adj Close    Volume
# Open       1.000000  0.999425  0.999575  0.998886   0.998886  0.501762
# High       0.999425  1.000000  0.999389  0.999640   0.999640  0.512944
# Low        0.999575  0.999389  1.000000  0.999447   0.999447  0.493496
# Close      0.998886  0.999640  0.999447  1.000000   1.000000  0.505169
# Adj Close  0.998886  0.999640  0.999447  1.000000   1.000000  0.505169
# Volume     0.501762  0.512944  0.493496  0.505169   0.505169  1.000000

# %%
pl.imshow(tesla.corr())
pl.colorbar()
pl.title("correlation")
pl.xticks(range(len(tesla.columns)), tss.columns, rotation=90)
pl.yticks(range(len(tesla.columns)), tss.columns);

# %%
ax = tesla.plot(y="Close")
pl.figure()
pl.plot(tesla.Close.values[1:] - tesla.Close.values[:-1])
